# %% [markdown]
# # 📊 Customer Churn Analysis – Python
#
# ## Step 1: Introduction
# Understanding why customers leave a telecom company (customer churn) by analyzing customer behavior, contracts, and services used.
#
# 📌 Objective:
# - Analyze churn rate
# - Identify churn-related features
# - Provide business insights to reduce churn

# %% [markdown]
# ## Step 2: Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: Set theme
sns.set(style="whitegrid")

# %% [markdown]
# ## Step 3: Load Dataset

# %%
# Load dataset
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Show top 5 rows
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Step 4: Understand the Data
#
# ### 4.1 Shape and Basic Info

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
# ...

# %% [markdown]
# ### 4.2 Statistical Summary

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# ### 4.3 Check Missing Values

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## Step 5: Data Cleaning
#
# ### 5.1 Convert Columns to Proper Data Types

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %% [markdown]
# ### 5.2 Drop Missing Values

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### 5.3 Final Null Check

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## Step 6: Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 6.1 Churn Count

# %%
sns.countplot(x='Churn', data=df)
plt.title("Churn Count")
plt.show()

# %% [markdown]
# ### 6.2 Churn by Contract Type

# %%
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title("Churn by Contract Type")
plt.show()

# %% [markdown]
# ### 6.3 Churn by Monthly Charges

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title("Monthly Charges by Churn")
plt.show()

# %% [markdown]
# ### 6.4 Churn by Tenure

# %%
sns.histplot(data=df, x='tenure', hue='Churn', multiple='stack', kde=True)
plt.title("Tenure Distribution by Churn")
plt.show()

# %% [markdown]
# ### 6.5 Churn by Tech Support

# %%
sns.countplot(x='TechSupport', hue='Churn', data=df)
plt.title("Churn by Tech Support")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Step 7: Key Insights
#
# - Overall churn rate is approximately 26%
# - Month-to-month contracts have the highest churn
# - Higher monthly charges → more likely to churn
# - Short-tenure customers churn more
# - Customers with tech support churn less

# %% [markdown]
# ## Step 8: Conclusion & Recommendations
#
# 📌 **Conclusion:**
# Our analysis revealed clear patterns in customer churn behavior:
#
# - Short-term contract customers are more likely to leave.
# - Higher monthly charges increase the risk of churn.
# - Customers without technical support or with short tenure are at greater risk.
#
# 📌 **Recommendations:**
# Based on these insights, the telecom company can reduce churn by:
#
# ✅ Encouraging long-term contracts (e.g. 1-year, 2-year plans)
# ✅ Offering promotions or discounts for new customers to stay longer
# ✅ Providing free or low-cost tech support to high-risk users
# ✅ Monitoring new customers (tenure < 10 months) more closely
#
# 🎯 With these actions, the company can improve customer retention, increase revenue stability, and reduce acquisition costs.
